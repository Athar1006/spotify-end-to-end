# %%
# %sql
drop table spotify_cata.silver.dim_artist

# %%
# %sql
drop table spotify_cata.silver.dim_date

# %%
# %sql
drop table spotify_cata.silver.dim_track

# %%
# %sql
drop table spotify_cata.silver.dim_user

# %%
# %sql
drop table spotify_cata.silver.fact_stream

# %% [markdown]
# Gold

# %%
# %sql
drop table spotify_cata.gold.dimdate

# %%
# %sql
drop table spotify_cata.gold.dimdate_stg

# %%
# %sql
drop table spotify_cata.gold.dimtrack

# %%
# %sql
drop table spotify_cata.gold.dimtrack_stg

# %%
# %sql
drop table spotify_cata.gold.dimuser

# %%
# %sql
drop table spotify_cata.gold.dimuser_stg

# %%
# %sql
drop table spotify_cata.gold.factstream

# %%
# %sql
drop table spotify_cata.gold.factstream_stg
